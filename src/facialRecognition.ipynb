# %%
# !pip install labelme tensorflow opencv-python matplotlib albumentations
# Out:
# Collecting labelme
#   Using cached labelme-5.10.1-py3-none-any.whl.metadata (1.3 kB)
# Collecting tensorflow
#   Using cached tensorflow-2.16.2-cp312-cp312-macosx_10_15_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: opencv-python in /Users/mercelisvaughan/code/svm-research/COSC354-SVM-Research/venv/lib/python3.12/site-packages (4.12.0.88)
# Requirement already satisfied: matplotlib in /Users/mercelisvaughan/code/svm-research/COSC354-SVM-Research/venv/lib/python3.12/site-packages (3.10.7)
# Collecting albumentations
#   Using cached albumentations-2.0.8-py3-none-any.whl.metadata (43 kB)
# Collecting imgviz (from labelme)
#   Using cached imgviz-1.7.6-py3-none-any.whl.metadata (6.2 kB)
# Collecting loguru (from labelme)
#   Using cached loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Collecting natsort>=7.1.0 (from labelme)
#   Using cached natsort-8.4.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: numpy in /Users/mercelisvaughan/code/svm-research/COSC354-SVM-Research/venv/lib/python3.12/site-packages (from labelme) (2.2.6)
# Collecting osam>=0.2.5 (from labelme)
#   Using cached osam-0.2.5-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: pillow>=2.8 in /Users/mercelisvaughan/code/svm-research/COSC354-SVM-Research/venv/lib/python3.12/site-packages (from labelme) (12.0.0)
# Collecting pyqt5>=5.14.0 (from labelme)
#   Using cached PyQt5-5.15.11.tar.gz (3.2 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [26 lines of output]
#       pyproject.toml: line 14: the legacy use of 'license' is deprecated and will be removed in SIP v7.0.0, use an SPDX license expression and 'license-files' instead
#       Traceback (most recent call last):
#         File "/Users/mercelisvaughan/code/svm-research/COSC354-SVM-Research/venv/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 353, in <module>
#           main()
#         File "/Users/mercelisvaughan/code/svm-research/COSC354-SVM-Research/venv/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/Users/mercelisvaughan/code/svm-research/COSC354-SVM-Research/venv/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 152, in prepare_metadata_for_build_wheel
#           whl_basename = backend.build_wheel(metadata_directory, config_settings)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/1s/0hrckt2s0kn03l7kj37kjwjm0000gn/T/pip-build-env-f2b_d6om/overlay/lib/python3.12/site-packages/sipbuild/api.py", line 28, in build_wheel
#           project = AbstractProject.bootstrap('wheel',
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/1s/0hrckt2s0kn03l7kj37kjwjm0000gn/T/pip-build-env-f2b_d6om/overlay/lib/python3.12/site-packages/sipbuild/abstract_project.py", line 74, in bootstrap
#           project.setup(pyproject, tool, tool_description)
#         File "/private/var/folders/1s/0hrckt2s0kn03l7kj37kjwjm0000gn/T/pip-build-env-f2b_d6om/overlay/lib/python3.12/site-packages/sipbuild/project.py", line 661, in setup
#           self.apply_user_defaults(tool)
#         File "/private/var/folders/1s/0hrckt2s0kn03l7kj37kjwjm0000gn/T/pip-install-asz24e0x/pyqt5_ad5eb7f8c29443a5b74b54c6b3726288/project.py", line 68, in apply_user_defaults
#           super().apply_user_defaults(tool)
#         File "/private/var/folders/1s/0hrckt2s0kn03l7kj37kjwjm0000gn/T/pip-build-env-f2b_d6om/overlay/lib/python3.12/site-packages/pyqtbuild/project.py", line 51, in apply_user_defaults
#           super().apply_user_defaults(tool)
#         File "/private/var/folders/1s/0hrckt2s0kn03l7kj37kjwjm0000gn/T/pip-build-env-f2b_d6om/overlay/lib/python3.12/site-packages/sipbuild/project.py", line 248, in apply_user_defaults
#           self.builder.apply_user_defaults(tool)
#         File "/private/var/folders/1s/0hrckt2s0kn03l7kj37kjwjm0000gn/T/pip-build-env-f2b_d6om/overlay/lib/python3.12/site-packages/pyqtbuild/builder.py", line 49, in apply_user_defaults
#           raise PyProjectOptionException('qmake',
#       sipbuild.pyproject.PyProjectOptionException
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import os
import time
import uuid
import cv2
import psutil

# %%
IMAGES_PATH = os.path.join('data','images')
number_images = 30

# %%
cap = cv2.VideoCapture(0)
for imgnum in range(number_images):
    print('Collecting image {}'.format(imgnum))
    ret, frame = cap.read()
    imgname = os.path.join(IMAGES_PATH,f'{str(uuid.uuid1())}.jpg')
    cv2.imwrite(imgname, frame)
    cv2.imshow('frame', frame)
    time.sleep(0.5)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# Collecting image 5
# Collecting image 6
# Collecting image 7
# Collecting image 8
# Collecting image 9
# Collecting image 10
# Collecting image 11
# Collecting image 12
# Collecting image 13
# Collecting image 14
# Collecting image 15
# Collecting image 16
# Collecting image 17
# Collecting image 18
# Collecting image 19
# Collecting image 20
# Collecting image 21
# Collecting image 22
# Collecting image 23
# Collecting image 24
# Collecting image 25
# Collecting image 26
# Collecting image 27
# Collecting image 28
# Collecting image 29

# %%
p = psutil.Process(os.getpid())
for t in p.threads():
    print(t)
# Out:
# pthread(id=1, user_time=1.713881, system_time=0.414831)
# pthread(id=2, user_time=5e-06, system_time=1.3e-05)
# pthread(id=3, user_time=0.003941, system_time=0.008577)
# pthread(id=4, user_time=0.155132, system_time=0.040581)
# pthread(id=5, user_time=0.00039, system_time=0.000234)
# pthread(id=6, user_time=6e-06, system_time=5.6e-05)
# pthread(id=7, user_time=1e-05, system_time=0.000126)
# pthread(id=8, user_time=6.7e-05, system_time=1.3e-05)
# pthread(id=9, user_time=1.2e-05, system_time=8e-06)
# pthread(id=10, user_time=0.001507, system_time=0.000558)
# pthread(id=11, user_time=0.009239, system_time=0.00364)
# pthread(id=12, user_time=0.002334, system_time=0.006564)
# pthread(id=13, user_time=0.00393, system_time=0.003405)
# pthread(id=14, user_time=0.100465, system_time=0.000654)
# pthread(id=15, user_time=0.100395, system_time=0.000481)
# pthread(id=16, user_time=0.100367, system_time=0.000564)
# pthread(id=17, user_time=0.099678, system_time=0.000497)
# pthread(id=18, user_time=0.100347, system_time=0.000499)
# pthread(id=19, user_time=0.099818, system_time=0.000632)
# pthread(id=20, user_time=0.100064, system_time=0.000325)
# pthread(id=21, user_time=0.003511, system_time=0.010177)
# pthread(id=22, user_time=5e-06, system_time=1.2e-05)
# pthread(id=23, user_time=3e-06, system_time=6e-06)
# pthread(id=24, user_time=0.018519, system_time=0.034337)
# pthread(id=25, user_time=0.013459, system_time=0.023603)
# pthread(id=26, user_time=0.028441, system_time=0.041458)
# pthread(id=27, user_time=0.02093, system_time=0.036049)
# pthread(id=28, user_time=0.044487, system_time=0.054608)
# pthread(id=29, user_time=0.016461, system_time=0.032609)
# pthread(id=30, user_time=0.021159, system_time=0.035742)
# pthread(id=31, user_time=0.018128, system_time=0.033698)
# pthread(id=32, user_time=0.020141, system_time=0.035466)
# pthread(id=33, user_time=0.020751, system_time=0.035186)
# pthread(id=34, user_time=0.031355, system_time=0.04466)
# pthread(id=35, user_time=0.049591, system_time=0.057765)
# pthread(id=36, user_time=0.029813, system_time=0.042438)

# %%
# !labelme
# Out:
# zsh:1: command not found: labelme

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Using cached tensorflow-2.16.2-cp312-cp312-macosx_10_15_x86_64.whl.metadata (4.1 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Using cached absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=23.5.26 (from tensorflow)
#   Using cached flatbuffers-25.9.23-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Using cached gast-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting h5py>=3.10.0 (from tensorflow)
#   Using cached h5py-3.15.1-cp312-cp312-macosx_10_13_x86_64.whl.metadata (3.0 kB)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Using cached libclang-18.1.1-py2.py3-none-macosx_10_9_x86_64.whl.metadata (5.2 kB)
# Collecting ml-dtypes~=0.3.1 (from tensorflow)
#   Using cached ml_dtypes-0.3.2-cp312-cp312-macosx_10_9_universal2.whl.metadata (20 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow)
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in /Users/mercelisvaughan/code/svm-research/COSC354-SVM-Research/venv/lib/python3.12/site-packages (from tensorflow) (25.0)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow)
#   Using cached protobuf-4.25.8-cp37-abi3-macosx_10_9_universal2.whl.metadata (541 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/mercelisvaughan/code/svm-research/COSC354-SVM-Research/venv/lib/python3.12/site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in /Users/mercelisvaughan/code/svm-research/COSC354-SVM-Research/venv/lib/python3.12/site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in /Users/mercelisvaughan/code/svm-research/COSC354-SVM-Research/venv/lib/python3.12/site-packages (from tensorflow) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Using cached termcolor-3.2.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/mercelisvaughan/code/svm-research/COSC354-SVM-Research/venv/lib/python3.12/site-packages (from tensorflow) (4.15.0)
# Collecting wrapt>=1.11.0 (from tensorflow)
#   Using cached wrapt-2.0.1-cp312-cp312-macosx_10_13_x86_64.whl.metadata (9.0 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Using cached grpcio-1.76.0.tar.gz (12.8 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting tensorboard<2.17,>=2.16 (from tensorflow)
#   Using cached tensorboard-2.16.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting keras>=3.0.0 (from tensorflow)
#   Using cached keras-3.12.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting numpy<2.0.0,>=1.26.0 (from tensorflow)
#   Using cached numpy-1.26.4-cp312-cp312-macosx_10_9_x86_64.whl.metadata (61 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow)
#   Using cached wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting rich (from keras>=3.0.0->tensorflow)
#   Using cached rich-14.2.0-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.0.0->tensorflow)
#   Using cached namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.0.0->tensorflow)
#   Using cached optree-0.18.0-cp312-cp312-macosx_10_13_x86_64.whl.metadata (34 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/mercelisvaughan/code/svm-research/COSC354-SVM-Research/venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mercelisvaughan/code/svm-research/COSC354-SVM-Research/venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mercelisvaughan/code/svm-research/COSC354-SVM-Research/venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mercelisvaughan/code/svm-research/COSC354-SVM-Research/venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2025.10.5)
# Collecting markdown>=2.6.8 (from tensorboard<2.17,>=2.16->tensorflow)
#   Using cached markdown-3.10-py3-none-any.whl.metadata (5.1 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.17,>=2.16->tensorflow)
#   Using cached tensorboard_data_server-0.7.2-py3-none-macosx_10_9_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.17,>=2.16->tensorflow)
#   Using cached werkzeug-3.1.4-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/mercelisvaughan/code/svm-research/COSC354-SVM-Research/venv/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow) (3.0.3)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.0.0->tensorflow)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/mercelisvaughan/code/svm-research/COSC354-SVM-Research/venv/lib/python3.12/site-packages (from rich->keras>=3.0.0->tensorflow) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Using cached tensorflow-2.16.2-cp312-cp312-macosx_10_15_x86_64.whl (259.7 MB)
# Using cached absl_py-2.3.1-py3-none-any.whl (135 kB)
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Using cached flatbuffers-25.9.23-py2.py3-none-any.whl (30 kB)
# Using cached gast-0.7.0-py3-none-any.whl (22 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Using cached h5py-3.15.1-cp312-cp312-macosx_10_13_x86_64.whl (3.4 MB)
# Using cached keras-3.12.0-py3-none-any.whl (1.5 MB)
# Using cached libclang-18.1.1-py2.py3-none-macosx_10_9_x86_64.whl (26.5 MB)
# Using cached ml_dtypes-0.3.2-cp312-cp312-macosx_10_9_universal2.whl (393 kB)
# Using cached numpy-1.26.4-cp312-cp312-macosx_10_9_x86_64.whl (20.3 MB)
# Using cached opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Using cached protobuf-4.25.8-cp37-abi3-macosx_10_9_universal2.whl (394 kB)
# Using cached tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
# Using cached termcolor-3.2.0-py3-none-any.whl (7.7 kB)
# Using cached wrapt-2.0.1-cp312-cp312-macosx_10_13_x86_64.whl (61 kB)
# Using cached markdown-3.10-py3-none-any.whl (107 kB)
# Using cached tensorboard_data_server-0.7.2-py3-none-macosx_10_9_x86_64.whl (4.8 MB)
# Using cached werkzeug-3.1.4-py3-none-any.whl (224 kB)
# Using cached wheel-0.45.1-py3-none-any.whl (72 kB)
# Using cached namex-0.1.0-py3-none-any.whl (5.9 kB)
# Using cached optree-0.18.0-cp312-cp312-macosx_10_13_x86_64.whl (369 kB)
# Using cached rich-14.2.0-py3-none-any.whl (243 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Building wheels for collected packages: grpcio
#   Building wheel for grpcio (pyproject.toml) ... done
#   Created wheel for grpcio: filename=grpcio-1.76.0-cp312-cp312-macosx_10_15_x86_64.whl size=5540928 sha256=96dd81320e0b23f10441051502aa4fdd6a315bb8d08fe1959c7faa032f43a4c1
#   Stored in directory: /Users/mercelisvaughan/Library/Caches/pip/wheels/fe/da/37/1b1ccd9146d06cf737253bd7295c16ad632dbf2fbf55256cf5
# Successfully built grpcio
# Installing collected packages: namex, libclang, flatbuffers, wrapt, wheel, werkzeug, termcolor, tensorboard-data-server, protobuf, optree, opt-einsum, numpy, mdurl, markdown, grpcio, google-pasta, gast, absl-py, tensorboard, ml-dtypes, markdown-it-py, h5py, astunparse, rich, keras, tensorflow
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# Successfully installed absl-py-2.3.1 astunparse-1.6.3 flatbuffers-25.9.23 gast-0.7.0 google-pasta-0.2.0 grpcio-1.76.0 h5py-3.15.1 keras-3.12.0 libclang-18.1.1 markdown-3.10 markdown-it-py-4.0.0 mdurl-0.1.2 ml-dtypes-0.3.2 namex-0.1.0 numpy-1.26.4 opt-einsum-3.4.0 optree-0.18.0 protobuf-4.25.8 rich-14.2.0 tensorboard-2.16.2 tensorboard-data-server-0.7.2 tensorflow-2.16.2 termcolor-3.2.0 werkzeug-3.1.4 wheel-0.45.1 wrapt-2.0.1
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import json
import numpy as np
from matplotlib import pyplot as plt

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 gpus = tf.config.experimental.list_physical_devices('GPU')
#       2 for gpu in gpus:
#       3     tf.config.experimental.set_memory_growth(gpu, True)
#
# NameError: name 'tf' is not defined
